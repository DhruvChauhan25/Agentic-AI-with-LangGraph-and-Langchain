# %% [markdown]
# # 1 - Synatax and Semantics

# %%
name='Dhruv'
Name='Chauhan'

print(name)
print(Name)
# Out:
# Dhruv
# Chauhan

# %%
#Arthimetic
a=10;b=5
add=a+b
sub=a-b
mult=a*b
div=a/b
floor_div=a//b
modulus=a%b
exponential=a**b

print(add)
print(sub)
print(mult)
print(div)
print(floor_div)
print(modulus)
print(exponential)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
##Not equal
str='dhruv';str2='Chauhan'
str3='dhruv';str4='dhruv'

print(str==str2)
print(str3!=str4)
# Out:
# False
# False

# %% [markdown]
# # Tuple

# %%
#Packed tuple

# %%
packed_tuple=1,'dhruv',3.44
packed_tuple
# Out:
# (1, 'dhruv', 3.44)

# %%
#Unpacked Tuple

# %%
a,b,c=packed_tuple

# %%
## Unpacking with *
numbers=(1,2,3,4,5,6)
first,*middle,last=numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
a={}

# %%
print(type(a))
# Out:
# <class 'dict'>

# %%
import shutil

# %%
#shutil.copyfile('source.txt','destination.txt')--->> it will copy the file content to the other file and make the file too

# %% [markdown]
# # Data Serialization

# %%
import json
data={'name':'Dhruv','age':23}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Dhruv", "age": 23}
# <class 'str'>
# {'name': 'Dhruv', 'age': 23}
# <class 'dict'>
